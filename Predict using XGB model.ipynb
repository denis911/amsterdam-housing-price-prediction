# %% [markdown]
# ## Use our trained XGB model to predict house prices in Amsterdam

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("HousingPrices-Amsterdam-August-2021.csv")
df.columns = df.columns.str.lower()

df['pc4'] = df.zip.str.split().str[0]
used_cols = ['pc4', 'area', 'room', 'price']
df = df[used_cols]

df.head(1)
# Out:
#     pc4  area  room     price
# 0  1091    64     3  685000.0

# %%
df.iloc[[100]] # 100	1092	67	3	500000.0
# Out:
#       pc4  area  room     price
# 100  1092    67     3  500000.0

# %%
# Load saved model from local drive

import pickle

with open("Ams_xgb_pipeline.17.11.2025.pkl", "rb") as f:
    loaded = pickle.load(f)

dv = loaded["dv"]
model = loaded["model"]

# %%
# Predict price of a row 100
import xgboost as xgb

# Load 1 data point
df_new = df.iloc[[100]]
real_price = df_new.price

# Log1p price
df_new.price = np.log1p(df_new.price)

# Transform using saved DictVectorizer
X_new = dv.transform(df_new.to_dict(orient='records'))

# Wrap in DMatrix
dnew = xgb.DMatrix(X_new)

# Predict
y_pred = model.predict(dnew)
exp_price = np.expm1(y_pred)
print(y_pred, exp_price, real_price)
# Out:
# C:\Users\d_local\AppData\Local\Temp\ipykernel_12584\2247003882.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.price = np.log1p(df_new.price)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 18
#      15 dnew = xgb.DMatrix(X_new)
#      17 # Predict
# ---> 18 y_pred = model.predict(dnew)
#      19 exp_price = np.expm1(y_pred)
#      20 print(y_pred, exp_price, real_price)
#
# File C:\tmp\amsterdam-housing-price-prediction\.venv\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File C:\tmp\amsterdam-housing-price-prediction\.venv\Lib\site-packages\xgboost\core.py:2689, in Booster.predict(self, data, output_margin, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    2687 if validate_features:
#    2688     fn = data.feature_names
# -> 2689     self._validate_features(fn)
#    2690 args = {
#    2691     "type": 0,
#    2692     "training": training,
#    (...)   2695     "strict_shape": strict_shape,
#    2696 }
#    2698 def assign_type(t: int) -> None:
#
# File C:\tmp\amsterdam-housing-price-prediction\.venv\Lib\site-packages\xgboost\core.py:3403, in Booster._validate_features(self, feature_names)
#    3400     return
#    3402 if feature_names is None and self.feature_names is not None:
# -> 3403     raise ValueError(
#    3404         "data did not contain feature names, but the following fields are expected: "
#    3405         + ", ".join(self.feature_names)
#    3406     )
#    3408 if self.feature_names != feature_names:
#    3409     dat_missing = set(cast(FeatureNames, self.feature_names)) - set(
#    3410         cast(FeatureNames, feature_names)
#    3411     )
#
# ValueError: data did not contain feature names, but the following fields are expected: area, pc4=1011, pc4=1012, pc4=1013, pc4=1014, pc4=1015, pc4=1016, pc4=1017, pc4=1018, pc4=1019, pc4=1021, pc4=1023, pc4=1024, pc4=1025, pc4=1027, pc4=1028, pc4=1031, pc4=1032, pc4=1033, pc4=1034, pc4=1035, pc4=1036, pc4=1051, pc4=1052, pc4=1053, pc4=1054, pc4=1055, pc4=1056, pc4=1057, pc4=1058, pc4=1059, pc4=1060, pc4=1061, pc4=1062, pc4=1063, pc4=1064, pc4=1065, pc4=1066, pc4=1067, pc4=1068, pc4=1069, pc4=1071, pc4=1072, pc4=1073, pc4=1074, pc4=1075, pc4=1076, pc4=1077, pc4=1078, pc4=1079, pc4=1081, pc4=1082, pc4=1083, pc4=1086, pc4=1087, pc4=1091, pc4=1092, pc4=1093, pc4=1094, pc4=1095, pc4=1096, pc4=1097, pc4=1098, pc4=1102, pc4=1103, pc4=1104, pc4=1106, pc4=1107, pc4=1108, pc4=1109, room

# %%
df_new
# Out:
#       pc4  area  room      price
# 100  1092    67     3  13.122365
